# %% [markdown]
# # Import Dependencies

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Import Data

# %%
# define the data path
datasource = "data/"

# %%
price_df = pd.read_excel(datasource+"price_df.xlsx")
# feature_df = pd.read_excel(datasource+"feature_df.xlsx")

# %%
price_df
# Out:
#              1993Q1     1993Q2     1993Q3     1993Q4     1994Q1     1994Q2  \
# 00088630  44.125000  42.291667  46.791667  42.500000  38.666667  32.416667
# 00101J10        NaN        NaN        NaN        NaN        NaN        NaN
# 00105510  34.875000  36.166667  37.666667  35.125000  32.500000  30.333333
# 00120410  40.458333  41.083333  40.458333  39.833333  39.791667  39.500000
# 00130H10  28.916667  30.333333  30.833333  30.666667  30.750000  31.083333
# 00154710        NaN        NaN        NaN        NaN        NaN        NaN
# 00195750  55.166667  56.166667  58.041667  60.125000  62.625000  63.083333
# 00206R10  73.833333  76.625000  64.583333  51.458333  39.208333  41.583333
# 00209A10        NaN        NaN        NaN        NaN        NaN        NaN
# 00282410  26.458333  26.583333  26.916667  26.875000  25.916667  25.541667
# 00287Y10        NaN        NaN        NaN        NaN        NaN        NaN
# ...
